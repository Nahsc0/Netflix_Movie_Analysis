# %% [markdown]
# # Assignment Questions:
#
# 1.Find number of movies relased in each decade
# from 1945, show a line chart to display this.
#
#
# 2. show the distirbution of run time features using an appropriate chart.
#
#
# 3. show barchart for movie genres.
#
#
# 4. show barchart for movie genres for children movies.
#
#
# 5. which of the genres have the highest runtime on the overal datatset and for each age group.

# %%
import pandas as pd
import numpy as numpy
import matplotlib.pyplot as plt
import seaborn as sns
# !pip install textblob

from textblob import TextBlob
# Out:
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
#      ---------------------------------------- 0.0/636.8 kB ? eta -:--:--
#       --------------------------------------- 10.2/636.8 kB ? eta -:--:--
#      - ----------------------------------- 30.7/636.8 kB 262.6 kB/s eta 0:00:03
#      - ----------------------------------- 30.7/636.8 kB 262.6 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 217.9 kB/s eta 0:00:03
#      --- ---------------------------------- 61.4/636.8 kB 15.3 kB/s eta 0:00:38
#      --- ---------------------------------- 61.4/636.8 kB 15.3 kB/s eta 0:00:38
#      ---- --------------------------------- 81.9/636.8 kB 20.9 kB/s eta 0:00:27
#      ---- --------------------------------- 81.9/636.8 kB 20.9 kB/s eta 0:00:27
#      ---- --------------------------------- 81.9/636.8 kB 20.9 kB/s eta 0:00:27
#      ----- -------------------------------- 92.2/636.8 kB 23.0 kB/s eta 0:00:24
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------ ------------------------------ 112.6/636.8 kB 28.4 kB/s eta 0:00:19
#      ------- ----------------------------- 122.9/636.8 kB 17.4 kB/s eta 0:00:30
#      ------- ----------------------------- 122.9/636.8 kB 17.4 kB/s eta 0:00:30
#      ------- ----------------------------- 122.9/636.8 kB 17.4 kB/s eta 0:00:30
#      -------- ---------------------------- 143.4/636.8 kB 20.1 kB/s eta 0:00:25
#      --------- --------------------------- 163.8/636.8 kB 23.0 kB/s eta 0:00:21
#      ---------- -------------------------- 174.1/636.8 kB 24.3 kB/s eta 0:00:20
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 194.6/636.8 kB 27.2 kB/s eta 0:00:17
#      ----------- ------------------------- 204.8/636.8 kB 19.4 kB/s eta 0:00:23
#      -------------- ---------------------- 245.8/636.8 kB 23.3 kB/s eta 0:00:17
#      -------------- ---------------------- 256.0/636.8 kB 24.3 kB/s eta 0:00:16
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ----------------- ------------------- 307.2/636.8 kB 29.1 kB/s eta 0:00:12
#      ------------------- ----------------- 327.7/636.8 kB 26.5 kB/s eta 0:00:12
#      ------------------- ----------------- 337.9/636.8 kB 27.3 kB/s eta 0:00:11
#      --------------------- --------------- 368.6/636.8 kB 29.7 kB/s eta 0:00:10
#      ---------------------- -------------- 389.1/636.8 kB 31.2 kB/s eta 0:00:08
#      ---------------------- -------------- 389.1/636.8 kB 31.2 kB/s eta 0:00:08
#      ---------------------- -------------- 389.1/636.8 kB 31.2 kB/s eta 0:00:08
#      ----------------------- ------------- 409.6/636.8 kB 32.6 kB/s eta 0:00:07
#      ----------------------- ------------- 409.6/636.8 kB 32.6 kB/s eta 0:00:07
#      ------------------------ ------------ 419.8/636.8 kB 33.2 kB/s eta 0:00:07
#      ------------------------ ------------ 430.1/636.8 kB 33.9 kB/s eta 0:00:07
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      -------------------------- ---------- 450.6/636.8 kB 35.4 kB/s eta 0:00:06
#      --------------------------- --------- 471.0/636.8 kB 32.0 kB/s eta 0:00:06
#      ----------------------------- ------- 501.8/636.8 kB 34.0 kB/s eta 0:00:04
#      -------------------------------- ---- 553.0/636.8 kB 37.4 kB/s eta 0:00:03
#      --------------------------------- --- 583.7/636.8 kB 39.4 kB/s eta 0:00:02
#      ------------------------------------  634.9/636.8 kB 42.8 kB/s eta 0:00:01
#      ------------------------------------- 636.8/636.8 kB 42.8 kB/s eta 0:00:00
# Requirement already satisfied: nltk>=3.1 in c:\users\yusuf nasir\anaconda3\lib\site-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in c:\users\yusuf nasir\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (8.0.4)
# Requirement already satisfied: joblib in c:\users\yusuf nasir\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\yusuf nasir\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\yusuf nasir\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.65.0)
# Requirement already satisfied: colorama in c:\users\yusuf nasir\anaconda3\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.6)
# Installing collected packages: textblob
# Successfully installed textblob-0.17.1

# %% [markdown]
# Importing data

# %%
df=pd.read_csv('imdb_movies_shows.csv')

# %%
df.head()
# Out:
#                                  title   type  release_year age_certification  \
# 0  Five Came Back: The Reference Films   SHOW          1945             TV-MA
# 1                          Taxi Driver  MOVIE          1976                 R
# 2      Monty Python and the Holy Grail  MOVIE          1975                PG
# 3                        Life of Brian  MOVIE          1979                 R
# 4                         The Exorcist  MOVIE          1973                 R
#
#    runtime                 genres production_countries  seasons    imdb_id  \
# 0       48      ['documentation']               ['US']      1.0        NaN
# 1      113     ['crime', 'drama']               ['US']      NaN  tt0075314
# 2       91  ['comedy', 'fantasy']               ['GB']      NaN  tt0071853
# 3       94             ['comedy']               ['GB']      NaN  tt0079470
# 4      133             ['horror']               ['US']      NaN  tt0070047
#
#    imdb_score  imdb_votes
# 0         NaN         NaN
# 1         8.3    795222.0
# 2         8.2    530877.0
# 3         8.0    392419.0
# 4         8.1    391942.0

# %%
df.tail()
# Out:
#                                    title   type  release_year  \
# 5801                           Fine Wine  MOVIE          2021
# 5802                      Edis Starlight  MOVIE          2021
# 5803                               Clash  MOVIE          2021
# 5804                      Shadow Parties  MOVIE          2021
# 5805  Mighty Little Bheem: Kite Festival   SHOW          2021
#
#      age_certification  runtime                             genres  \
# 5801               NaN      100               ['romance', 'drama']
# 5802               NaN       74         ['music', 'documentation']
# 5803               NaN       88                ['family', 'drama']
# 5804               NaN      116             ['action', 'thriller']
# 5805               NaN        0  ['family', 'comedy', 'animation']
#
#      production_countries  seasons     imdb_id  imdb_score  imdb_votes
# 5801               ['NG']      NaN  tt13857480         6.9        39.0
# 5802                   []      NaN         NaN         NaN         NaN
# 5803         ['NG', 'CA']      NaN  tt14620732         6.5        32.0
# 5804                   []      NaN  tt10168094         6.2         9.0
# 5805                   []      1.0  tt13711094         8.8        16.0

# %%
df.describe()
# Out:
#        release_year      runtime      seasons   imdb_score    imdb_votes
# count   5806.000000  5806.000000  2047.000000  5283.000000  5.267000e+03
# mean    2016.013434    77.643989     2.165608     6.533447  2.340719e+04
# std        7.324883    39.474160     2.636207     1.160932  8.713432e+04
# min     1945.000000     0.000000     1.000000     1.500000  5.000000e+00
# 25%     2015.000000    44.000000     1.000000     5.800000  5.210000e+02
# 50%     2018.000000    84.000000     1.000000     6.600000  2.279000e+03
# 75%     2020.000000   105.000000     2.000000     7.400000  1.014400e+04
# max     2022.000000   251.000000    42.000000     9.600000  2.268288e+06

# %%
df.isnull().sum()
# Out:
# title                      1
# type                       0
# release_year               0
# age_certification       2610
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 3759
# imdb_id                  444
# imdb_score               523
# imdb_votes               539
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5806 entries, 0 to 5805
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   title                 5805 non-null   object
#  1   type                  5806 non-null   object
#  2   release_year          5806 non-null   int64
#  3   age_certification     3196 non-null   object
#  4   runtime               5806 non-null   int64
#  5   genres                5806 non-null   object
#  6   production_countries  5806 non-null   object
#  7   seasons               2047 non-null   float64
#  8   imdb_id               5362 non-null   object
#  9   imdb_score            5283 non-null   float64
#  10  imdb_votes            5267 non-null   float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 499.1+ KB

# %%
df['age_certification'].value_counts()
# Out:
# age_certification
# TV-MA    841
# R        575
# TV-14    470
# PG-13    440
# PG       246
# TV-PG    186
# G        131
# TV-Y7    112
# TV-Y     105
# TV-G      76
# NC-17     14
# Name: count, dtype: int64

# %%
df['age_certification'].unique()
# Out:
# array(['TV-MA', 'R', 'PG', 'TV-14', 'G', 'PG-13', nan, 'TV-PG', 'TV-Y',
#        'TV-G', 'TV-Y7', 'NC-17'], dtype=object)

# %%
df['release_year'].unique()
# Out:
# array([1945, 1976, 1975, 1979, 1973, 1969, 1971, 1964, 1980, 1967, 1966,
#        1961, 1954, 1958, 1968, 1977, 1972, 1963, 1960, 1956, 1953, 1974,
#        1959, 1962, 1978, 1986, 1989, 1984, 1990, 1987, 1983, 1982, 1981,
#        1988, 1985, 1995, 2000, 1997, 1994, 1996, 1999, 1998, 1993, 1992,
#        1991, 2008, 2010, 2004, 2005, 2003, 2009, 2007, 2006, 2001, 2002,
#        2012, 2011, 2014, 2013, 2015, 2016, 2017, 2018, 2019, 2020, 2022,
#        2021], dtype=int64)

# %%
df['genres'].value_counts()
# Out:
# genres
# ['comedy']                                            510
# ['drama']                                             350
# ['documentation']                                     320
# ['comedy', 'drama']                                   141
# ['drama', 'comedy']                                   128
#                                                      ...
# ['drama', 'family', 'comedy', 'music']                  1
# ['drama', 'thriller', 'western']                        1
# ['comedy', 'thriller', 'drama', 'action', 'crime']      1
# ['romance', 'drama', 'history', 'european']             1
# ['family', 'comedy', 'animation']                       1
# Name: count, Length: 1626, dtype: int64

# %%
type(df['genres'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Data Cleaning
# Dropping null values

# %%
df= df.dropna(subset=['title'])

# %%
df[df['title'].isnull()]
# Out:
# Empty DataFrame
# Columns: [title, type, release_year, age_certification, runtime, genres, production_countries, seasons, imdb_id, imdb_score, imdb_votes]
# Index: []

# %%
df= df.dropna(subset=['imdb_id'])

# %%
df[df['imdb_id'].isnull()]
# Out:
# Empty DataFrame
# Columns: [title, type, release_year, age_certification, runtime, genres, production_countries, seasons, imdb_id, imdb_score, imdb_votes]
# Index: []

# %% [markdown]
# Converting genres and production countries to csv

# %%
df['genres'] = df['genres'].str.replace('[', '')
df['genres'] = df['genres'].str.replace(']', '')

# %%
df.head()
# Out:
#                              title   type  release_year age_certification  \
# 1                      Taxi Driver  MOVIE          1976                 R
# 2  Monty Python and the Holy Grail  MOVIE          1975                PG
# 3                    Life of Brian  MOVIE          1979                 R
# 4                     The Exorcist  MOVIE          1973                 R
# 5     Monty Python's Flying Circus   SHOW          1969             TV-14
#
#    runtime                genres production_countries  seasons    imdb_id  \
# 1      113      'crime', 'drama'               ['US']      NaN  tt0075314
# 2       91   'comedy', 'fantasy'               ['GB']      NaN  tt0071853
# 3       94              'comedy'               ['GB']      NaN  tt0079470
# 4      133              'horror'               ['US']      NaN  tt0070047
# 5       30  'comedy', 'european'               ['GB']      4.0  tt0063929
#
#    imdb_score  imdb_votes
# 1         8.3    795222.0
# 2         8.2    530877.0
# 3         8.0    392419.0
# 4         8.1    391942.0
# 5         8.8     72895.0

# %%
df['production_countries'] = df['production_countries'].str.replace('[', '')
df['production_countries'] = df['production_countries'].str.replace(']', '')

# %%
df.head()
# Out:
#                              title   type  release_year age_certification  \
# 1                      Taxi Driver  MOVIE          1976                 R
# 2  Monty Python and the Holy Grail  MOVIE          1975                PG
# 3                    Life of Brian  MOVIE          1979                 R
# 4                     The Exorcist  MOVIE          1973                 R
# 5     Monty Python's Flying Circus   SHOW          1969             TV-14
#
#    runtime                genres production_countries  seasons    imdb_id  \
# 1      113      'crime', 'drama'                 'US'      NaN  tt0075314
# 2       91   'comedy', 'fantasy'                 'GB'      NaN  tt0071853
# 3       94              'comedy'                 'GB'      NaN  tt0079470
# 4      133              'horror'                 'US'      NaN  tt0070047
# 5       30  'comedy', 'european'                 'GB'      4.0  tt0063929
#
#    imdb_score  imdb_votes
# 1         8.3    795222.0
# 2         8.2    530877.0
# 3         8.0    392419.0
# 4         8.1    391942.0
# 5         8.8     72895.0

# %% [markdown]
# ## Question 1.Find number of movies relased in each decade from 1945, show a line chart to display this.

# %%
df['decade'] = df['release_year'] // 10 * 10

# %%
decade_counts = df.groupby('decade').size()

# %%
plt.figure(figsize=(10,6))
decade_counts.plot.line()
plt.title('Number of Movies Released by Decade')
plt.xlabel('Decade')
plt.ylabel('Counts')
plt.show()

# %% [markdown]
# ## Question 2. Show The Distirbution of Run Time Features Using an Appropriate Chart.

# %%
plt.figure(figsize=(10,6))
df['runtime'].hist(bins=30, edgecolor='black')
plt.title('Distribution of Movie Runtimes')
plt.xlabel('Runtime (minutes)')
plt.ylabel('Counts')
plt.show()

# %% [markdown]
# ## Question 3. Show Barchart For Movie Genres.

# %%
 df['genres'].unique()
# Out:
# array(["'crime', 'drama'", "'comedy', 'fantasy'", "'comedy'", ...,
#        "'crime', 'comedy', 'drama', 'thriller', 'action'",
#        "'music', 'romance', 'comedy'", "'family', 'comedy', 'animation'"],
#       dtype=object)

# %%
df.genres.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 1                      'crime', 'drama'
# 2                   'comedy', 'fantasy'
# 3                              'comedy'
# 4                              'horror'
# 5                  'comedy', 'european'
#                      ...
# 5800                           'comedy'
# 5801                 'romance', 'drama'
# 5803                  'family', 'drama'
# 5804               'action', 'thriller'
# 5805    'family', 'comedy', 'animation'
# Name: genres, Length: 5361, dtype: object>

# %%
df.genres.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 5361 entries, 1 to 5805
# Series name: genres
# Non-Null Count  Dtype
# --------------  -----
# 5361 non-null   object
# dtypes: object(1)
# memory usage: 83.8+ KB

# %%
# Define a function to map genres to broader categories
def map_to_category(genre):
    if 'action' in genre.lower() or 'crime' in genre.lower() or 'thriller' in genre.lower():
        return 'Crime'
    elif 'comedy' in genre.lower() or 'fantasy' in genre.lower():
        return 'Comedy'
    elif 'drama' in genre.lower():
        return 'Drama'
    elif 'romance' in genre.lower() or 'music' in genre.lower():
        return 'Romance'
    elif 'family' in genre.lower() or 'animation' in genre.lower():
        return 'Family'
    else:
        return 'Other'

# %%
# Apply the function to create a new 'category' column
df['category'] = df['genres'].apply(map_to_category)

# %%
# Display the result
print(df[['genres', 'category']])
# Out:
#                                genres category
# 1                    'crime', 'drama'   Action
# 2                 'comedy', 'fantasy'   Comedy
# 3                            'comedy'   Comedy
# 4                            'horror'    Other
# 5                'comedy', 'european'   Comedy
# ...                               ...      ...
# 5800                         'comedy'   Comedy
# 5801               'romance', 'drama'    Drama
# 5803                'family', 'drama'    Drama
# 5804             'action', 'thriller'   Action
# 5805  'family', 'comedy', 'animation'   Comedy
#
# [5361 rows x 2 columns]

# %%
# Count the occurrences of each category
category_counts = df['category'].value_counts()

# %%
# Plot a bar chart
plt.figure(figsize=(10, 6))
category_counts.plot(kind='bar', color='skyblue')
plt.title('Count of Movies by Category')
plt.xlabel('Category')
plt.ylabel('Count')

# Rotate x-axis labels to be horizontal
plt.xticks(rotation=0)

# Add legend
plt.legend()
plt.show()

# %% [markdown]
# ## Question 4. show barchart for movie genres for children movies.

# %%
genre_counts = children_movies_df['genres'].value_counts()

# %%
# Children genres in the dataset
children_movies_df['genres'].value_counts().head(10).plot(kind='barh')

plt.show()

# %% [markdown]
# ## Question 5. Which of The Genres Have The Highest Runtime on The Overal Datatset and For Each Age Group.

# %%
# Average runtime by Ratings
df.groupby('age_group_ratings')['runtime'].mean().plot(kind='barh')
plt.xlabel('Runtime')
plt.show()

# %%
# Average runtime by Category in the whole Dataset
df.groupby('category')['runtime'].mean().plot(kind='barh')
plt.xlabel('Runtime')
plt.show()

# %% [markdown]
# # Other 5 Individual Question:
#
# 6- Trends of Content Produced on Netflix Anually.
#
# 7-Sentiment Analysis From 2005 to 2020 Base on Genres.
#
# 8- Age Certification Dsitribution.
#
# 9- IMDb Score Distribution by Age Certification
#
# 10-

# %% [markdown]
# ## Question 6. Trends of Content Produced on Netflix Anually.

# %%
import plotly.express as px 

df1 = df[['type', 'release_year']]

df1 = df1.rename(columns={"release_year":"Release Year", "type": "Type"})

df2 = df1.groupby(['Release Year', 'Type']).size().reset_index(name="Total Counts")

# %%
df2
# Out:
#      Release Year   Type  Total Counts
# 0            1953  MOVIE             1
# 1            1954  MOVIE             2
# 2            1956  MOVIE             1
# 3            1958  MOVIE             1
# 4            1959  MOVIE             1
# ..            ...    ...           ...
# 101          2020   SHOW           256
# 102          2021  MOVIE           416
# 103          2021   SHOW           283
# 104          2022  MOVIE           101
# 105          2022   SHOW           102
#
# [106 rows x 3 columns]

# %%
df2 = df2[df2['Release Year']>=2000]
graph = px.line(df2, x = "Release Year", y ="Total Counts", color = "Type", 
                title = "Trends of Content Produced on Netflix From The Year 2000 to 2020.")

graph.show()
# Out:
# <div>                            <div id="9a8ae985-93a2-4995-84c8-c0cdaea0c0d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a8ae985-93a2-4995-84c8-c0cdaea0c0d0")) {                    Plotly.newPlot(                        "9a8ae985-93a2-4995-84c8-c0cdaea0c0d0",                        [{"hovertemplate":"Type=MOVIE<br>Release Year=%{x}<br>Total Counts=%{y}<extra></extra>","legendgroup":"MOVIE","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"MOVIE","orientation":"v","showlegend":true,"x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[8,17,13,22,25,26,36,39,47,44,52,69,74,98,108,136,214,378,451,476,416,416,101],"yaxis":"y","type":"scatter"},{"hovertemplate":"Type=SHOW<br>Release Year=%{x}<br>Total Counts=%{y}<extra></extra>","legendgroup":"SHOW","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"SHOW","orientation":"v","showlegend":true,"x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[5,6,8,9,5,10,12,10,14,17,21,30,31,37,44,92,138,177,289,283,256,283,102],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewid ...

# %% [markdown]
# ## Question 7. Sentiment Analysis Base on The Genre

# %%
df3 = df[['release_year', 'genres']]

df3 = df3.rename(columns = {"release_year":"Release Year", "genres": "Genre"})

for index, row in df3.iterrows():
    d=row['Genre']
    testimonial = TextBlob(d)
    p = testimonial.sentiment.polarity
    if p==0:
        sent = 'Neutral'
    elif p>0:
        sent = 'Positive'
    else:
        sent = 'Negative'
    df3.loc[[index, 2], 'Sentiment']=sent
df3 = df3.groupby(['Release Year', 'Sentiment']).size().reset_index(name='Total Count')

df3 = df3[df3['Release Year']>2005]

bargraph = px.bar(df3, x = "Release Year", y ="Total Count", color="Sentiment", title="Sentiment Analysis On Netflix Datset From 2005 to 2020.")

# %%
bargraph.show()
# Out:
# <div>                            <div id="ce83dfac-6dec-40ab-8fa0-dc7eac0dd4b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce83dfac-6dec-40ab-8fa0-dc7eac0dd4b6")) {                    Plotly.newPlot(                        "ce83dfac-6dec-40ab-8fa0-dc7eac0dd4b6",                        [{"alignmentgroup":"True","hovertemplate":"Sentiment=Neutral<br>Release Year=%{x}<br>Total Count=%{y}<extra></extra>","legendgroup":"Neutral","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Neutral","offsetgroup":"Neutral","orientation":"v","showlegend":true,"textposition":"auto","x":[2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[41,36,36,46,51,73,75,108,115,181,282,469,617,640,561,576,171],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sentiment=Positive<br>Release Year=%{x}<br>Total Count=%{y}<extra></extra>","legendgroup":"Positive","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Positive","offsetgroup":"Positive","orientation":"v","showlegend":true,"textposition":"auto","x":[2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[7,13,25,15,22,26,30,27,37,47,70,86,123,119,111,123,32],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth ...

# %% [markdown]
# ## Question 8- Age Certification Dsitribution.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming df is your DataFrame
# Example data:
# df['age_certification'] = ...

# Create a bar chart for age certification distribution
age_cert_counts = df['age_certification'].value_counts()
age_cert_counts.plot(kind='bar', color='skyblue')
plt.title('Age Certification Distribution')
plt.xlabel('Age Certification')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ## Question 9.IMDb Score Distribution by Age Certification

# %%
# Create a box plot to show IMDb score distribution for each age certification
plt.figure(figsize=(10, 6))
sns.boxplot(x='age_certification', y='imdb_score', data=df, palette='viridis')
plt.title('IMDb Score Distribution by Age Certification')
plt.xlabel('Age Certification')
plt.ylabel('IMDb Score')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame
# Example data:
# df['imdb_score'] = ...

# Select relevant numeric columns
numeric_columns = df.select_dtypes(include='number')

# Create a correlation matrix
correlation_matrix = numeric_columns.corr()

# Create a heatmap to visualize correlations
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Heatmap')
plt.xticks(rotation=0)
plt.show()

# %%
children_movies_df.value_counts()
# Out:
# title                           type  release_year  age_certification  runtime  genres                                                         production_countries  seasons  imdb_id     imdb_score  imdb_votes  decade  age_group_ratings
# 3Below: Tales of Arcadia        SHOW  2018          TV-Y7              22       'comedy', 'scifi', 'action', 'animation', 'family', 'fantasy'  'US'                  2.0      tt7736544   7.7         5927.0      2010    Good for Children    1
# Secrets of Summer               SHOW  2022          TV-Y               30       'drama', 'family', 'music'                                     'ES'                  1.0      tt12379170  5.9         110.0       2020    Good for Children    1
# Rainbow High                    SHOW  2020          TV-Y               6        'comedy', 'family', 'animation'                                'US'                  3.0      tt13488080  6.4         116.0       2020    Good for Children    1
# Rainbow Rangers                 SHOW  2018          TV-Y               22       'family', 'fantasy', 'animation'                               'US'                  2.0      tt7967882   5.8         187.0       2010    Good for Children    1
# Rainbow Ruby                    SHOW  2016          TV-Y               11       'animation', 'comedy', 'family', 'fantasy'                     'CN'                  4.0      tt5828144   6.5         77.0        2010    Good for Children    1
#                                                                                                                                                                                                                                               ..
# Home: Adventures with Tip & Oh  SHOW  2016          TV-Y7              21       'comedy', 'family', 'fantasy', 'scifi', 'animation'            'US'                  4.0      tt5759196   5.9         603.0       2010    Good for Children    1
# Hotel Transylvania: The Series  SHOW  2017          TV-Y7              16       'comedy', 'family', 'fantasy', 'horror', 'animation'           'US'                  2.0      tt4858114   5.5         694.0       2010    Good for Children    1
# I Heart Arlo                    SHOW  2021          TV-Y7              15       'comedy', 'family', 'animation'                                'US'                  1.0      tt13573450  7.0         204.0       2020    Good for Children    1
# Inspector Gadget                SHOW  2015          TV-Y               21       'action', 'comedy', 'family', 'scifi', 'animation'             'CA', 'US'            4.0      tt3910690   4.5         614.0       2010    Good for Children    1
# Три кота                        SHOW  2015          TV-Y               5        'scifi', 'comedy', 'family', 'animation'                       'RU'                  3.0      tt7038964   6.8         95.0        2010    Good for Children    1
# Name: count, Length: 270, dtype: int64
